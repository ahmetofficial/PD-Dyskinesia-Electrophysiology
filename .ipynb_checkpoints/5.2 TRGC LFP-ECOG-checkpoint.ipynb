# %%
# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path
from scipy import signal

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp
from statsmodels.stats.multitest import multipletests

from joblib import Parallel, delayed
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

import utils_io, utils_trgc, utils_plotting_trgc, utils_plotting

from lib_data import DATA_IO

# %%
PATH_CURR = os.path.abspath(os.curdir)    # current code
PATH      = (str(Path(PATH_CURR).parent)) # data repository: upper directory where datasets situated
fs        = 2048

# %% [markdown]
# # 1. Data Load & Preprocess

# %%
# load ECoG events
EVENTS_ECOG            = utils_io.load_ECoG_events(event_category="tapping", fs=2048)
EVENTS_ECOG_LID        = EVENTS_ECOG['controlateral']['LID']
EVENTS_ECOG_noLID      = EVENTS_ECOG['controlateral']['noLID']
# load LFP events
EVENTS_LFP             = utils_io.load_LFP_events(event_category="tapping", stn_areas=["motor"], fs=2048)
EVENTS_LFP_MOTOR_LID   = EVENTS_LFP['motor']['controlateral']['LID']
EVENTS_LFP_MOTOR_noLID = EVENTS_LFP['motor']['controlateral']['noLID']

# %%
# add state information
EVENTS_ECOG_noLID["severity"]                                                              = "MED-OFF"
EVENTS_ECOG_noLID.loc[(EVENTS_ECOG_noLID['event_start_time'] >= 30), 'severity']           = 'MED-ON'
EVENTS_ECOG_LID["severity"]                                                                = "LID"
EVENTS_LFP_MOTOR_noLID["severity"]                                                         = "MED-OFF"
EVENTS_LFP_MOTOR_noLID.loc[(EVENTS_LFP_MOTOR_noLID['event_start_time'] >= 30), 'severity'] = 'MED-ON'
EVENTS_LFP_MOTOR_LID["severity"]                                                           = "LID"

dataset_LFP  = pd.concat([EVENTS_LFP_MOTOR_noLID, EVENTS_LFP_MOTOR_LID], ignore_index=True)
dataset_ECOG = pd.concat([EVENTS_ECOG_LID, EVENTS_ECOG_noLID], ignore_index=True)

dataset_LFP  = dataset_LFP[dataset_LFP.patient.isin(dataset_ECOG.patient.unique().tolist())]
dataset_LFP.reset_index(drop=True, inplace=True)

dataset_LFP  = dataset_LFP[['patient', 'event_no', 'LFP_hemisphere', 'LFP_channel', 'pre_event_recording', 'event_recording', 'post_event_recording', 'severity']]
dataset_ECOG = dataset_ECOG[['patient', 'event_no', 'ECoG_hemisphere', 'ECoG_channel', 'pre_event_recording', 'event_recording', 'post_event_recording', 'severity']]

del EVENTS_ECOG, EVENTS_ECOG_LID, EVENTS_ECOG_noLID, EVENTS_LFP, EVENTS_LFP_MOTOR_LID, EVENTS_LFP_MOTOR_noLID

# %% [markdown]
# # 2. Time-Reversed Granger Causality

# %% [markdown]
# ## 2.1 Tapping Activity

# %%
connectivity_side = "ipsilateral"
data_gc           = []

for state in ["MED-OFF", "MED-ON", "LID"]:
    for direction in ["lfp->ecog", "ecog->lfp"]:
        for patient in dataset_ECOG[dataset_ECOG.severity==state].patient.unique():
            for segment in ["pre_event", "event", "post_event"]:

                print(f"processing patient {patient} | {direction} direction | {state} state | {segment} segment... ")
                patient_gc = utils_trgc.measure_granger_causality_between_STN_and_cortex(dataset_LFP       = dataset_LFP, 
                                                                                         dataset_ECOG      = dataset_ECOG, 
                                                                                         state             = state, 
                                                                                         direction         = direction, 
                                                                                         patient           = patient, 
                                                                                         segment           = segment, 
                                                                                         connectivity_side = connectivity_side,
                                                                                         fs                = fs, 
                                                                                         n_iteration       = 100)
                if not (np.isscalar(patient_gc) and np.isnan(patient_gc)):
                    data_gc.append(patient_gc)

data_gc = pd.concat(data_gc, ignore_index=True)
# Out:
# processing patient 009 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | lfp->ecog direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 010 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 010 | lfp->ecog direction | MED-OFF state | event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 010 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 013 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> >>> >>> Patient 013 does not have ipsilateral side LFP recordings with ECOG for MED-OFF state...
# processing patient 013 | lfp->ecog direction | MED-OFF state | event segment...
# >>> >>> >>> Patient 013 does not have ipsilateral side LFP recordings with ECOG for MED-OFF state...
# processing patient 013 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> >>> >>> Patient 013 does not have ipsilateral side LFP recordings with ECOG for MED-OFF state...
# processing patient 014 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | lfp->ecog direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 016 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 016 | lfp->ecog direction | MED-OFF state | event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 016 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 017 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | lfp->ecog direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 020 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 020 | lfp->ecog direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 020 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | ecog->lfp direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 010 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 010 | ecog->lfp direction | MED-OFF state | event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 010 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 013 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> >>> >>> Patient 013 does not have ipsilateral side LFP recordings with ECOG for MED-OFF state...
# processing patient 013 | ecog->lfp direction | MED-OFF state | event segment...
# >>> >>> >>> Patient 013 does not have ipsilateral side LFP recordings with ECOG for MED-OFF state...
# processing patient 013 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> >>> >>> Patient 013 does not have ipsilateral side LFP recordings with ECOG for MED-OFF state...
# processing patient 014 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | ecog->lfp direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 016 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 016 | ecog->lfp direction | MED-OFF state | event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 016 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-OFF state to estimate connectivity...
# processing patient 017 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | ecog->lfp direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 020 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 020 | ecog->lfp direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 020 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | MED-OFF state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | MED-OFF state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | MED-OFF state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 010 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 010 | lfp->ecog direction | MED-ON state | event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 010 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 013 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 013 | lfp->ecog direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 013 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | lfp->ecog direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 016 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 016 | lfp->ecog direction | MED-ON state | event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 016 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 017 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | lfp->ecog direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | lfp->ecog direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 010 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 010 | ecog->lfp direction | MED-ON state | event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 010 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> >>> >>> Patient 010 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 013 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 013 | ecog->lfp direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 013 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | ecog->lfp direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 014 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 016 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 016 | ecog->lfp direction | MED-ON state | event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 016 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for MED-ON state to estimate connectivity...
# processing patient 017 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | ecog->lfp direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 017 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | ecog->lfp direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | MED-ON state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | MED-ON state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | MED-ON state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 008 | lfp->ecog direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 008 | lfp->ecog direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 008 | lfp->ecog direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | lfp->ecog direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | lfp->ecog direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | lfp->ecog direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 012 | lfp->ecog direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 012 | lfp->ecog direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 012 | lfp->ecog direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 016 | lfp->ecog direction | LID state | pre_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for LID state to estimate connectivity...
# processing patient 016 | lfp->ecog direction | LID state | event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for LID state to estimate connectivity...
# processing patient 016 | lfp->ecog direction | LID state | post_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for LID state to estimate connectivity...
# processing patient 019 | lfp->ecog direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | lfp->ecog direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | lfp->ecog direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> >>> time reversed granger causality estimation failed for the channel...
# processing patient 021 | lfp->ecog direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | lfp->ecog direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | lfp->ecog direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | lfp->ecog direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 008 | ecog->lfp direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 008 | ecog->lfp direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 008 | ecog->lfp direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | ecog->lfp direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | ecog->lfp direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 009 | ecog->lfp direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 012 | ecog->lfp direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 012 | ecog->lfp direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 012 | ecog->lfp direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 016 | ecog->lfp direction | LID state | pre_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for LID state to estimate connectivity...
# processing patient 016 | ecog->lfp direction | LID state | event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for LID state to estimate connectivity...
# processing patient 016 | ecog->lfp direction | LID state | post_event segment...
# >>> >>> >>> Patient 016 does not have LFP or ECOG recordings for LID state to estimate connectivity...
# processing patient 019 | ecog->lfp direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | ecog->lfp direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 019 | ecog->lfp direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> >>> time reversed granger causality estimation failed for the channel...
# processing patient 021 | ecog->lfp direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 021 | ecog->lfp direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 022 | ecog->lfp direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | LID state | pre_event segment...
# >>> pre-event recordings have consistent length  : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | LID state | event segment...
# >>> event recordings have consistent length      : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...
# processing patient 023 | ecog->lfp direction | LID state | post_event segment...
# >>> post event recordings have consistent length : True
# >>> >>> bootstrap testing with 100 iterations
# >>> >>> >>> 100 iteration completed...

# %%
data_gc.to_pickle(DATA_IO.path_events + "granger_causality/ipsilateral_connectivity_.pkl")

# %% [markdown]
# ## 2.2 Baseline Recordings

# %%
baseline_gc = utils_connectivity.measure_baseline_granger_causality_between_STN_and_cortex(connectivity_side="ipsilateral", fs=fs)
baseline_gc.to_pickle(DATA_IO.path_events + "granger_causality/baseline_ipsilateral_connectivity.pkl")
# Out:
# Patient 008: does not have right hemisphere baseline recordings
# Patient 009: does not have right hemisphere baseline recordings
# Patient 010: does not have left hemisphere baseline recordings
# Patient 012: does not have left hemisphere baseline recordings
# Patient 013: does not have left hemisphere baseline recordings
# Patient 014: does not have left hemisphere baseline recordings
# Patient 016: does not have left hemisphere baseline recordings
# Patient 017: does not have left hemisphere baseline recordings
# Patient 020: does not have left hemisphere baseline recordings
# Patient 021: does not have left hemisphere baseline recordings
# Patient 022: does not have left hemisphere baseline recordings
# Patient 023: does not have left hemisphere baseline recordings
# Patient 101: does not have right hemisphere baseline recordings
# Patient 101: does not have left hemisphere baseline recordings
# Patient 102: does not have right hemisphere baseline recordings
# Patient 102: does not have left hemisphere baseline recordings
# Patient 103: does not have right hemisphere baseline recordings
# Patient 103: does not have left hemisphere baseline recordings
# Patient 105: does not have right hemisphere baseline recordings
# Patient 105: does not have left hemisphere baseline recordings
# Patient 107: does not have right hemisphere baseline recordings
# Patient 107: does not have left hemisphere baseline recordings
# Patient 108: does not have right hemisphere baseline recordings
# Patient 108: does not have left hemisphere baseline recordings
# Patient 109: does not have right hemisphere baseline recordings
# Patient 109: does not have left hemisphere baseline recordings
# Patient 110: does not have right hemisphere baseline recordings
# Patient 110: does not have left hemisphere baseline recordings
# processing patient 008 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 008 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 009 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 009 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 010 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 010 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 012 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 012 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 013 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 013 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 014 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 014 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 016 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 016 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 017 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 017 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 019 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 019 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 020 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 020 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 021 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 021 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 022 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 022 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 023 | lfp->ecog direction | REST state ...
# >>> event recordings have consistent length      : True
# processing patient 023 | ecog->lfp direction | REST state ...
# >>> event recordings have consistent length      : True

# %% [markdown]
# ## 2.3 Normalization

# %%
baseline_gc   = pd.read_pickle(DATA_IO.path_events + "granger_causality/baseline_ipsilateral_connectivity.pkl")
taps_gc       = pd.read_pickle(DATA_IO.path_events + "granger_causality/ipsilateral_connectivity.pkl")
normalized_gc = utils_connectivity.normalize_gc_by_baseline(taps_gc, baseline_gc)

# %% [markdown]
# # 3. Statistical Test

# %%
taps_gc = pd.read_pickle(DATA_IO.path_events + "granger_causality/ipsilateral_connectivity.pkl")

# %% [markdown]
# ## 3.1 Clinical State-Wise Differences [MED-OFF vs MED-ON & MED-ON vs LID]

# %%
results_lme_state = []

for frequency_band in ["theta", "alpha", "beta_low", "beta_high", "gamma"]:
    for segment in ["pre_event", "event", "post_event"]:
        
        results_lme_state.append(utils_trgc.compare_trgc_strength_across_states(dataset=taps_gc, direction="ecog->lfp", frequency_band=frequency_band, segment=segment))

results_lme_state                     = pd.concat(results_lme_state, ignore_index=True)
# correct the p-values for each comparison separately (i.e. correct all pvalues for MED-OFF vs MED-ON)
results_lme_state["pvalue_corrected"] = results_lme_state.groupby("reference_group")["pvalue"].transform(lambda p: multipletests(p, method="holm")[1])

# %%
plt = utils_plotting.get_figure_template()
ax1 = plt.subplot2grid((77, 66), (0, 0)  , colspan=9, rowspan=6)
ax2 = plt.subplot2grid((77, 66), (0, 20) , colspan=9, rowspan=6)
ax3 = plt.subplot2grid((77, 66), (0, 40) , colspan=9, rowspan=6)

ax4 = plt.subplot2grid((77, 66), (15, 0) , colspan=9, rowspan=6)
ax5 = plt.subplot2grid((77, 66), (15, 20), colspan=9, rowspan=6)
ax6 = plt.subplot2grid((77, 66), (15, 40), colspan=9, rowspan=6)

ax1 = utils_plotting_trgc.plot_stats_between_states(results_lme_state, event_segment="pre_event" , reference_group="MED-OFF", comparison_group="MED-ON", axis=ax1)
ax2 = utils_plotting_trgc.plot_stats_between_states(results_lme_state, event_segment="event"     , reference_group="MED-OFF", comparison_group="MED-ON", axis=ax2)
ax3 = utils_plotting_trgc.plot_stats_between_states(results_lme_state, event_segment="post_event", reference_group="MED-OFF", comparison_group="MED-ON", axis=ax3)

ax4 = utils_plotting_trgc.plot_stats_between_states(results_lme_state, event_segment="pre_event" , reference_group="MED-ON", comparison_group="LID", axis=ax4)
ax5 = utils_plotting_trgc.plot_stats_between_states(results_lme_state, event_segment="event"     , reference_group="MED-ON", comparison_group="LID", axis=ax5)
ax6 = utils_plotting_trgc.plot_stats_between_states(results_lme_state, event_segment="post_event", reference_group="MED-ON", comparison_group="LID", axis=ax6)

plt.savefig(DATA_IO.path_figure + "granger_causality/lme_ECOGSTN_TFGC_between_states.svg", dpi=1200)

# %%
results_lme_state[results_lme_state.segment=="event"]
# Out:
#    reference_group comparison_group  direction segment frequency_band  \
# 2          MED-OFF           MED-ON  ecog->lfp   event          theta
# 3           MED-ON              LID  ecog->lfp   event          theta
# 8          MED-OFF           MED-ON  ecog->lfp   event          alpha
# 9           MED-ON              LID  ecog->lfp   event          alpha
# 14         MED-OFF           MED-ON  ecog->lfp   event       beta_low
# 15          MED-ON              LID  ecog->lfp   event       beta_low
# 20         MED-OFF           MED-ON  ecog->lfp   event      beta_high
# 21          MED-ON              LID  ecog->lfp   event      beta_high
# 26         MED-OFF           MED-ON  ecog->lfp   event          gamma
# 27          MED-ON              LID  ecog->lfp   event          gamma
#
#     coefficient   z_score        pvalue  CI_lower  CI_upper  pvalue_corrected
# 2      0.004514  1.997924  4.572493e-02  0.000086  0.008943      4.572493e-02
# 3     -0.005912 -2.399342  1.642457e-02 -0.010742 -0.001083      4.817492e-02
# 8      0.008447  4.207463  2.582542e-05  0.004512  0.012382      5.165084e-05
# 9     -0.008197 -3.712372  2.053262e-04 -0.012525 -0.003869      1.481312e-03
# 14     0.011089  5.796513  6.770794e-09  0.007339  0.014838      2.708317e-08
# 15    -0.008334 -3.899156  9.652858e-05 -0.012523 -0.004145      8.687572e-04
# 20     0.010087  6.970419  3.159983e-12  0.007251  0.012923      2.527986e-11
# 21    -0.005356 -3.288588  1.006913e-03 -0.008549 -0.002164      6.041476e-03
# 26     0.012406  9.297847  1.433184e-20  0.009791  0.015022      2.006458e-19
# 27    -0.006624 -4.370326  1.240609e-05 -0.009594 -0.003653      1.364670e-04

# %% [markdown]
# ## 3.2 Segment-Wise Differences Within Clinical States

# %%
dataset = taps_gc[taps_gc.source_type=="ECOG"].copy()
dataset = dataset.drop(["source_hemisphere", "source_index", "target_hemisphere", "target_index", "direction",
                        "gc_gamma_III", "pvalue_theta", "pvalue_alpha", "pvalue_beta_low", "pvalue_beta_high", "pvalue_gamma"], axis=1)

# first melt dataset into long format
dataset = dataset.melt(id_vars    = ["source_channel", "target_channel", "patient", "state", "segment"], # unique combinations
                       value_vars = ["gc_theta", "gc_alpha", "gc_beta_low", "gc_beta_high", "gc_gamma"],
                       var_name   = "frequency_band",
                       value_name = "gc_value")

# remove "gc_" prefix
dataset["frequency_band"] = dataset["frequency_band"].str.replace("gc_", "", regex=False)

# %%
results_lme_segment = []

for state in ["MED-OFF", "MED-ON", "LID"]:
    for frequency_band in ["theta", "alpha", "beta_low", "beta_high", "gamma"]:

        results = utils_trgc.compare_trgc_strength_across_segments_within_states(dataset=dataset, state=state, frequency_band=frequency_band)
        results_lme_segment.extend(results)

results_lme_segment                     = pd.DataFrame(results_lme_segment)
results_lme_segment["pvalue_corrected"] = results_lme_segment.groupby("state")["pvalue"].transform(lambda p: multipletests(p, method="holm")[1])

# %%
def plot_stats_between_segments_within_state(data, state, reference_group, comparison_group, axis):

    data_subset          = data[(data.reference_group==reference_group) & (data.comparison_group==comparison_group) & (data.state==state)].copy()
    data_subset['color'] = np.where(data_subset['pvalue_corrected'] > 0.05,'#ccccccff',  # non-significant
                                    np.where(data_subset['coefficient'] > 0,
                                             '#99e2b4ff',  # significant positive
                                             '#ef3c2dff'   # significant negative
                                            )
                                   )
    
    axis = sns.scatterplot(data=data_subset, y="frequency_band", x='z_score', c=data_subset.color.to_list(), s=15, ax=axis)
    axis.set_xlim([-10,10])
    axis.set_title(f"{state} | {comparison_group} - {reference_group}", fontsize=utils_plotting.LABEL_SIZE)
    axis.set_ylabel("")
    utils_plotting.set_axis(axis)

    return axis

# %%
plt = utils_plotting.get_figure_template()

ax1 = plt.subplot2grid((77, 66), (0 , 0 ), colspan=9, rowspan=6)
ax2 = plt.subplot2grid((77, 66), (0 , 18), colspan=9, rowspan=6)
ax3 = plt.subplot2grid((77, 66), (12, 0 ), colspan=9, rowspan=6)
ax4 = plt.subplot2grid((77, 66), (12, 18), colspan=9, rowspan=6)
ax5 = plt.subplot2grid((77, 66), (24, 0 ), colspan=9, rowspan=6)
ax6 = plt.subplot2grid((77, 66), (24, 18), colspan=9, rowspan=6)

ax1 = plot_stats_between_segments_within_state(results_lme_segment, state="MED-OFF", reference_group="event", comparison_group="pre_event" , axis=ax1)
ax2 = plot_stats_between_segments_within_state(results_lme_segment, state="MED-OFF", reference_group="event", comparison_group="post_event", axis=ax2)

ax3 = plot_stats_between_segments_within_state(results_lme_segment, state="MED-ON" , reference_group="event", comparison_group="pre_event" , axis=ax3)
ax4 = plot_stats_between_segments_within_state(results_lme_segment, state="MED-ON" , reference_group="event", comparison_group="post_event", axis=ax4)

ax5 = plot_stats_between_segments_within_state(results_lme_segment, state="LID"    , reference_group="event", comparison_group="pre_event" , axis=ax5)
ax6 = plot_stats_between_segments_within_state(results_lme_segment, state="LID"    , reference_group="event", comparison_group="post_event", axis=ax6)

plt.savefig(DATA_IO.path_figure + "granger_causality/lme_ECOGSTN_TFGC_between_segments.svg", dpi=1200)

# %% [markdown]
# ## 3.3 Differences Brain Cortices

# %%
# load MNI Coordinates of ECoG channels
MNI_ECoG_channels                = pd.read_pickle(DATA_IO.path_coordinates + "MNI_ECoG_channels.pkl")
MNI_ECoG_channels                = MNI_ECoG_channels[["patient", "hemisphere", "channel", "AAL3_cortex"]]
MNI_ECoG_channels["AAL3_cortex"] = MNI_ECoG_channels["AAL3_cortex"].replace({"Motor cortex": "motor", "Sensory cortex": "sensory",
                                                                   "Prefrontal cortex": "prefrontal", 'Parietal cortex':"parietal"})

dataset = taps_gc[taps_gc.source_type=="ECOG"].copy()
dataset = dataset.drop(["source_index", "target_hemisphere", "target_index", "direction",
                        "gc_gamma_III", "pvalue_theta", "pvalue_alpha", "pvalue_beta_low", "pvalue_beta_high", "pvalue_gamma"], axis=1)

# merge ECOG channel position with TRGC dataset
dataset = dataset.merge(MNI_ECoG_channels, left_on=["patient", "source_hemisphere", "source_channel"],
                               right_on=["patient", "hemisphere", "channel"], how="left", suffixes=("", "_source"))
dataset = dataset.drop(columns=["hemisphere", "channel"])

# %%
results_lme_cortices = []

for state in ["MED-OFF", "MED-ON", "LID"]:
    for frequency_band in ["theta", "alpha", "beta_low", "beta_high", "gamma"]:
       for segment in ["pre_event", "event", "post_event"]:

            results = utils_trgc.compare_trgc_strength_across_segments_within_cortical_areas(dataset        = dataset, 
                                                                                             state          = state,
                                                                                             segment        = segment,
                                                                                             frequency_band = frequency_band)
            results_lme_cortices.extend(results)

results_lme_cortices                     = pd.DataFrame(results_lme_cortices)
results_lme_cortices["pvalue_corrected"] = results_lme_cortices.groupby(["comparison_group"])["pvalue"].transform(lambda p: multipletests(p, method="holm")[1])

# %%
results_lme_cortices[results_lme_cortices.pvalue<=0.05]
# Out:
#     reference_group comparison_group  direction    state     segment  \
# 25            motor         parietal  ecog->lfp  MED-OFF  post_event
# 34            motor         parietal  ecog->lfp  MED-OFF  post_event
# 118           motor         parietal  ecog->lfp      LID   pre_event
#
#     frequency_band  coefficient   z_score    pvalue  CI_lower  CI_upper  \
# 25        beta_low    -0.011033 -2.218163  0.026544 -0.020781 -0.001284
# 34       beta_high    -0.008993 -2.011237  0.044300 -0.017757 -0.000229
# 118      beta_high    -0.005625 -2.129208  0.033237 -0.010804 -0.000447
#
#      pvalue_corrected
# 25                1.0
# 34                1.0
# 118               1.0

# %% [markdown]
# # 4. Plotting Average TFGC for Cortex [Separate Event Segments]

# %%
taps_gc = pd.read_pickle(DATA_IO.path_events + "granger_causality/ipsilateral_connectivity.pkl")

# %% [markdown]
# ## 4.1 TFGC MED-OFF

# %%
vmin=0.005; vmax=0.020

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "pre_event" , frequency_band = "gamma", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "event"     , frequency_band = "gamma", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "post_event", frequency_band = "gamma", vmin=vmin, vmax=vmax)

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "pre_event" , frequency_band = "beta_high", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "event"     , frequency_band = "beta_high", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "post_event", frequency_band = "beta_high", vmin=vmin, vmax=vmax)

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "pre_event" , frequency_band = "beta_low", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "event"     , frequency_band = "beta_low", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-OFF", segment = "post_event", frequency_band = "beta_low", vmin=vmin, vmax=vmax)

# %% [markdown]
# ## 4.2 TFGC MED-ON

# %%
vmin=0.005; vmax=0.020

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "pre_event" , frequency_band = "gamma", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "event"     , frequency_band = "gamma", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "post_event", frequency_band = "gamma", vmin=vmin, vmax=vmax)

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "pre_event" , frequency_band = "beta_high", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "event"     , frequency_band = "beta_high", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "post_event", frequency_band = "beta_high", vmin=vmin, vmax=vmax)

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "pre_event" , frequency_band = "beta_low", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "event"     , frequency_band = "beta_low", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "MED-ON", segment = "post_event", frequency_band = "beta_low", vmin=vmin, vmax=vmax)

# %% [markdown]
# ## 4.3 TFGC LID

# %%
vmin=0.005; vmax=0.020

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "pre_event" , frequency_band = "gamma", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "event"     , frequency_band = "gamma", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "post_event", frequency_band = "gamma", vmin=vmin, vmax=vmax)

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "pre_event" , frequency_band = "beta_high", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "event"     , frequency_band = "beta_high", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "post_event", frequency_band = "beta_high", vmin=vmin, vmax=vmax)

utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "pre_event" , frequency_band = "beta_low", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "event"     , frequency_band = "beta_low", vmin=vmin, vmax=vmax)
utils_plotting_trgc.plot_gc_connectivity_for_ECOG_channels(taps_gc, state = "LID", segment = "post_event", frequency_band = "beta_low", vmin=vmin, vmax=vmax)
